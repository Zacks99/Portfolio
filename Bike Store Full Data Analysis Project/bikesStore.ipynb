# %%
import pandas as pd 
import numpy as np

# %%
bikes=pd.read_csv('BikeStores_data_1.csv',sep=',')

# %%
bikes.head()
# Out:
#    order_id            customers        city state order_date  total_units  \
# 0         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
# 1         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            1
# 2         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
# 3         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            1
# 4         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
#
#    revenue                                    product_name  \
# 0  1199.98            Electra Townie Original 7D EQ - 2016
# 1   599.99  Electra Townie Original 7D EQ - Women's - 2016
# 2  3098.00                          Surly Straggler - 2016
# 3  2899.99                        Trek Fuel EX 8 29 - 2016
# 4  3599.98           Trek Remedy 29 Carbon Frameset - 2016
#
#          category_name brand_name        store_name        sales_rep
# 0    Cruisers Bicycles    Electra  Santa Cruz Bikes  Mireya Copeland
# ...

# %%
bikes.dtypes
# Out:
# order_id           int64
# customers         object
# city              object
# state             object
# order_date        object
# total_units        int64
# revenue          float64
# product_name      object
# category_name     object
# brand_name        object
# store_name        object
# sales_rep         object
# dtype: object

# %%
bikes.columns
# Out:
# Index(['order_id', 'customers', 'city', 'state', 'order_date', 'total_units',
#        'revenue', 'product_name', 'category_name', 'brand_name', 'store_name',
#        'sales_rep'],
#       dtype='object')

# %%
bikes['order_date']=pd.to_datetime(bikes['order_date'])
# Out:
# C:\Users\zakaria\AppData\Local\Temp\ipykernel_6176\4090196290.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   bikes['order_date']=pd.to_datetime(bikes['order_date'])

# %%
bikes.head(50)
# Out:
#     order_id            customers                city state order_date  \
# 0          1  Johnathan Velazquez          Pleasanton    CA 2016-01-01
# 1          1  Johnathan Velazquez          Pleasanton    CA 2016-01-01
# 2          1  Johnathan Velazquez          Pleasanton    CA 2016-01-01
# 3          1  Johnathan Velazquez          Pleasanton    CA 2016-01-01
# 4          1  Johnathan Velazquez          Pleasanton    CA 2016-01-01
# 5          2   Jaqueline Cummings  Huntington Station    NY 2016-01-01
# 6          2   Jaqueline Cummings  Huntington Station    NY 2016-01-01
# 7          3     Joshua Robertson           Patchogue    NY 2016-02-01
# 8          3     Joshua Robertson           Patchogue    NY 2016-02-01
# 9          4            Nova Hess              Duarte    CA 2016-03-01
# 10         5           Arla Ellis               Utica    NY 2016-03-01
# 11         5           Arla Ellis               Utica    NY 2016-03-01
# ...

# %%
bikes.to_csv('bikes_upgrated_format.csv')
